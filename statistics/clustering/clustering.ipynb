# %%
include("K-Mean_Clustering.jl")
# Out:
# GetCentroid (generic function with 7 methods)

# %%
EuclidianDistance((5,4), (1,1))
# Out:
# 5.0

# %%
GetCentroid([(1,5), (3, -3)])
# Out:
# (2.0, 1.0)

# %%
GetCentroid([(1,5), (3, -3), (8,7)])
# Out:
# (4.0, 3.0)

# %%
GetCentroid([(-6,7), (-5,-1), (4, 3)])
# Out:
# (-2.3333333333333335, 3.0)

# %%
# Calculate the centroids
centroid1 = GetCentroid([(1,6), (2,4), (0,2)])
centroid2 = GetCentroid([(6,4), (8,4)])

# Pass the centroids as separate arguments
distance = EuclidianDistance(centroid1, centroid2)
# Out:
# 6.0
