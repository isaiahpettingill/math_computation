# %% [markdown]
# # Euclidian Algorithm

# %%
include("Euclidian.jl")
# Out:
# Z_LinearCombo (generic function with 2 methods)

# %%
println(GCD(133, 91))
println(Z_LinearCombo(133, 91))
# Out:
# 7
# (-2, 3)

# %%
Z_LinearCombo(377, 221)
# Out:
# (-7, 12)

# %%
include("PrimeFactorization.jl")
using ..PrimeFactorization
# Out:
# WARNING: replacing module PrimeFactorization.
# WARNING: using PrimeFactorization.SmallestFactor in module Main conflicts with an existing identifier.
# WARNING: using PrimeFactorization.CanonicalPrimeFactorization in module Main conflicts with an existing identifier.

# %%
CanonicalPrimeFactorization(60)
# Out:
# 3-element Vector{Any}:
#  (2, 2)
#  (3, 1)
#  (5, 1)

# %%
CanonicalPrimeFactorization(989564974649)
# Out:
# 3-element Vector{Any}:
#  (41, 1)
#  (7669, 1)
#  (3147181, 1)

# %%
CanonicalPrimeFactorization(989564974641)
# Out:
# 5-element Vector{Any}:
#  (3, 2)
#  (109, 1)
#  (233, 1)
#  (379, 1)
#  (11423, 1)

# %%
CanonicalPrimeFactorization(993814444444586644)
# Out:
# 3-element Vector{Any}:
#  (2, 2)
#  (11, 2)
#  (2053335629017741, 1)

# %%
CanonicalPrimeFactorization(4444444444444444444)
# Out:
# 2-element Vector{Any}:
#  (2, 2)
#  (1111111111111111111, 1)

# %%
CanonicalPrimeFactorization(698979496649163135)
# Out:
# 5-element Vector{Any}:
#  (3, 1)
#  (5, 1)
#  (7, 2)
#  (42043, 1)
#  (22619520787, 1)

# %%
CanonicalPrimeFactorization(2^9*3^20*7^3)
# Out:
# 3-element Vector{Any}:
#  (2, 9)
#  (3, 20)
#  (7, 3)
